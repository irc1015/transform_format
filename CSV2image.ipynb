# %%
import numpy as np
import matplotlib.pyplot as plt

MAX_EPOCHES = 100

x = np.arange(1, MAX_EPOCHES + 1, 1)

# %%
y_value_1 = []
y_value_2 = []
y_value_3 = []

read_values_1 = np.genfromtxt('/Users/zhuzhirui/Desktop/1/1.csv', delimiter=',')#transform into numpy
read_values_2 = np.genfromtxt('/Users/zhuzhirui/Desktop/1/2.csv', delimiter=',')#transform into numpy
read_values_3 = np.genfromtxt('/Users/zhuzhirui/Desktop/1/3.csv', delimiter=',')#transform into numpy
'''
0:train/box_loss 
1:train/obj_loss 
2:train/cls_loss 
3:metrics/precision 
4:metrics/recall
5:metrics/mAP_0.5 
6:metrics/map_0.5:0.95 
7:val/box_loss 
8:val/obj_loss 
9:val/cls_loss
10:x/lr0 
11:x/lr1 
12:x/lr2
'''

n1_1 = np.delete(read_values_1, 0, 0)#remove 1st line (name line)
n2_1 = np.delete(n1_1, 0, 1)#remove 1st column (epoch number colomn)

n1_2 = np.delete(read_values_2, 0, 0)#remove 1st line (name line)
n2_2 = np.delete(n1_2, 0, 1)#remove 1st column (epoch number colomn)

n1_3 = np.delete(read_values_3, 0, 0)#remove 1st line (name line)
n2_3 = np.delete(n1_3, 0, 1)#remove 1st column (epoch number colomn)

values_1 = n2_1[:MAX_EPOCHES]
values_2 = n2_2[:MAX_EPOCHES]
values_3 = n2_3[:]

print('csv1 shape is {}'.format(values_1.shape))
print('csv2 shape is {}'.format(values_2.shape))
print('csv3 shape is {}'.format(values_3.shape))
# Out:
# csv1 shape is (100, 13)
# csv2 shape is (100, 13)
# csv3 shape is (69, 13)

# %%
precision_1 = [i for i in values_1[:, 3]]
precision_1 = np.stack(precision_1)

precision_2 = [i for i in values_2[:, 3]]
precision_2 = np.stack(precision_2)

precision_3 = [None for i in range(100)]
precision_3 = np.stack(precision_3)
for i in range(len(values_3[:, 3])):
    precision_3[i] = values_3[i, 3]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, precision_1, label='YOLOv5s')
ax.plot(x, precision_2, label='YOLOv5s6')
ax.plot(x, precision_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='precision')
ax.legend(loc='upper right')
plt.show()

# %%
recall_1 = [i for i in values_1[:, 4]]
recall_1 = np.stack(recall_1)

recall_2 = [i for i in values_2[:, 4]]
recall_2 = np.stack(recall_2)

recall_3 = [None for i in range(100)]
recall_3 = np.stack(recall_3)
for i in range(len(values_3[:, 4])):
    recall_3[i] = values_3[i, 4]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, recall_1, label='YOLOv5s')
ax.plot(x, recall_2, label='YOLOv5s6')
ax.plot(x, recall_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='recall')
ax.legend(loc='lower right')
plt.show()

# %%
mAP1_1 = [i for i in values_1[:, 5]]
mAP1_1 = np.stack(mAP1_1)

mAP1_2 = [i for i in values_2[:, 5]]
mAP1_2 = np.stack(mAP1_2)

mAP1_3 = [None for i in range(100)]
mAP1_3 = np.stack(mAP1_3)
for i in range(len(values_3[:, 5])):
    mAP1_3[i] = values_3[i, 5]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, mAP1_1, label='YOLOv5s')
ax.plot(x, mAP1_2, label='YOLOv5s6')
ax.plot(x, mAP1_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='mAP 0.5')
ax.legend(loc='lower right')
plt.show()

# %%
mAP2_1 = [i for i in values_1[:, 6]]
mAP2_1 = np.stack(mAP2_1)

mAP2_2 = [i for i in values_2[:, 6]]
mAP2_2 = np.stack(mAP2_2)

mAP2_3 = [None for i in range(100)]
mAP2_3 = np.stack(mAP2_3)
for i in range(len(values_3[:, 6])):
    mAP2_3[i] = values_3[i, 6]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, mAP2_1, label='YOLOv5s')
ax.plot(x, mAP2_2, label='YOLOv5s6')
ax.plot(x, mAP2_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='mAP 0.5-0.95')
ax.legend(loc='lower right')
plt.show()

# %%
box_loss_1 = [i for i in values_1[:, 7]]
box_loss_1 = np.stack(box_loss_1)

box_loss_2 = [i for i in values_2[:, 7]]
box_loss_2 = np.stack(box_loss_2)

box_loss_3 = [None for i in range(100)]
box_loss_3 = np.stack(box_loss_3)
for i in range(len(values_3[:, 7])):
    box_loss_3[i] = values_3[i, 7]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, box_loss_1, label='YOLOv5s')
ax.plot(x, box_loss_2, label='YOLOv5s6')
ax.plot(x, box_loss_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='box_loss')
ax.legend(loc='upper right')
plt.show()

# %%
obj_loss_1 = [i for i in values_1[:, 8]]
obj_loss_1 = np.stack(obj_loss_1)

obj_loss_2 = [i for i in values_2[:, 8]]
obj_loss_2 = np.stack(obj_loss_2)

obj_loss_3 = [None for i in range(100)]
obj_loss_3 = np.stack(obj_loss_3)
for i in range(len(values_3[:, 8])):
    obj_loss_3[i] = values_3[i, 8]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, obj_loss_1, label='YOLOv5s')
ax.plot(x, obj_loss_2, label='YOLOv5s6')
ax.plot(x, obj_loss_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='obj_loss')
ax.legend(loc='upper right')
plt.show()

# %%
cls_loss_1 = [i for i in values_1[:, 9]]
cls_loss_1 = np.stack(cls_loss_1)

cls_loss_2 = [i for i in values_2[:, 9]]
cls_loss_2 = np.stack(cls_loss_2)

cls_loss_3 = [None for i in range(100)]
cls_loss_3 = np.stack(cls_loss_3)
for i in range(len(values_3[:, 9])):
    cls_loss_3[i] = values_3[i, 9]

fig, ax = plt.subplots(figsize=(7, 5))
ax.plot(x, cls_loss_1, label='YOLOv5s')
ax.plot(x, cls_loss_2, label='YOLOv5s6')
ax.plot(x, cls_loss_3, label='YOLOv5m6')
ax.set(xlabel='epoch', ylabel='cls_loss')
ax.legend(loc='upper right')
plt.show()

# %%
y_value_3 = [None for i in range(100)]
y_value_3 = np.stack(y_value_3)
print(y_value_3)
print(y_value_3.shape)
# Out:
# [None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None]
# (100,)
